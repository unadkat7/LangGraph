# %%
from langgraph.graph import StateGraph,START,END
from langchain_google_genai import ChatGoogleGenerativeAI
from typing import TypedDict,Annotated
from dotenv import load_dotenv
from pydantic import BaseModel, Field
import operator

# %%
load_dotenv()
# Out:
# True

# %%
model = ChatGoogleGenerativeAI(model="gemini-2.5-flash")

# %%
class EvaluationSchema(BaseModel):

    feedback: str = Field(description="Detailed feedback for the essay")
    score: int = Field(description="Score out of 10",ge=0, le=10)

# %%
structred_model = model.with_structured_output(EvaluationSchema)

# %%
essay = """# Role of Artificial Intelligence in India

## Introduction

Artificial Intelligence (AI) is one of the most transformative technologies of the 21st century. It refers to the ability of machines and computer systems to perform tasks that typically require human intelligence, such as learning, reasoning, problem-solving, and decision-making. AI has become an integral part of modern life, influencing industries, businesses, healthcare, education, and governance. India, with its large population, skilled workforce, and rapidly growing digital economy, has emerged as one of the leading countries adopting AI technologies. The role of AI in India's development is significant, as it has the potential to improve productivity, enhance public services, and contribute to economic growth.

## AI and Economic Growth

Artificial Intelligence is expected to become a major driver of India's economy. By automating repetitive tasks and improving operational efficiency, AI can increase productivity across various sectors. Businesses use AI for customer service, data analysis, fraud detection, and supply chain management. Startups and established companies alike are investing heavily in AI-powered solutions.

India's thriving IT industry provides a strong foundation for AI development. The country has a large pool of software engineers, data scientists, and researchers who contribute to AI innovations. As AI adoption increases, it is expected to create new business opportunities, attract investments, and generate employment in emerging fields such as machine learning, robotics, and data analytics.

## AI in Healthcare

Healthcare is one of the sectors where AI has immense potential in India. AI-powered systems can assist doctors in diagnosing diseases, analyzing medical images, and predicting health risks. Machine learning algorithms can detect conditions such as cancer, diabetes, and heart disease at an early stage, improving treatment outcomes.

Telemedicine platforms use AI to provide healthcare services to people living in remote areas. AI chatbots can offer preliminary medical advice and schedule appointments. During health emergencies, AI helps monitor disease outbreaks and supports healthcare planning. By reducing costs and improving accessibility, AI can strengthen India's healthcare infrastructure.

## AI in Agriculture

Agriculture is the backbone of India's economy, employing millions of people. AI can help farmers increase productivity and reduce losses. AI-based systems analyze weather patterns, soil conditions, and crop health to provide recommendations for planting, irrigation, and fertilization.

Drones equipped with AI can monitor crop growth and identify pest infestations. Smart irrigation systems optimize water usage, helping farmers conserve resources. Predictive analytics enable farmers to make informed decisions about crop selection and market prices. These technologies contribute to sustainable agriculture and improve farmers' incomes.

## AI in Education

Artificial Intelligence is transforming the education sector by making learning more personalized and accessible. AI-powered educational platforms adapt to individual learning styles and provide customized study materials. Students can receive instant feedback and track their progress.

Virtual tutors and intelligent learning systems help bridge educational gaps, especially in rural areas where access to quality education may be limited. AI also assists teachers by automating administrative tasks such as grading and attendance management, allowing them to focus more on teaching.

## AI in Governance and Public Services

The Indian government is increasingly using AI to improve governance and public service delivery. AI helps analyze large volumes of data to make informed policy decisions and identify areas requiring intervention. Smart city initiatives use AI for traffic management, waste disposal, energy conservation, and public safety.

AI-powered systems assist in tax administration, fraud detection, and digital public services. Government departments can use predictive analytics to improve disaster management and emergency response. These applications increase transparency, efficiency, and accountability in governance.

## AI in Banking and Finance

The banking and financial sectors in India have widely adopted AI technologies. Banks use AI for fraud detection, credit scoring, customer support, and risk management. AI-powered chatbots provide 24/7 customer assistance and resolve common queries efficiently.

Digital payment platforms employ AI to detect suspicious transactions and enhance cybersecurity. Financial institutions use predictive models to assess loan applications and manage investment portfolios. These innovations improve customer experience and strengthen financial security.

## AI in Manufacturing and Industry

AI is revolutionizing manufacturing by enabling smart factories and automated production systems. AI-powered robots perform repetitive and hazardous tasks with high precision. Predictive maintenance systems monitor machinery and prevent unexpected breakdowns, reducing operational costs.

Indian industries use AI to optimize supply chains, improve quality control, and increase production efficiency. The adoption of AI supports the growth of advanced manufacturing and enhances global competitiveness.

## AI in Transportation

Artificial Intelligence plays a vital role in improving transportation systems. AI helps optimize traffic flow, reduce congestion, and improve road safety. Navigation applications use AI to suggest the fastest routes based on real-time traffic conditions.

Railways and airlines use AI for scheduling, maintenance, and passenger services. Autonomous vehicle research and intelligent transportation systems have the potential to transform mobility in India in the future.

## AI and Employment

While AI creates new job opportunities, it also raises concerns about automation replacing certain types of work. Routine and repetitive tasks may become automated, affecting traditional jobs. However, AI also generates demand for skilled professionals in areas such as machine learning, cybersecurity, software development, and data science.

To maximize the benefits of AI, India must invest in education, digital literacy, and skill development programs. Upskilling the workforce will help individuals adapt to changing job requirements and participate in the AI-driven economy.

## Challenges of AI in India

Despite its advantages, AI faces several challenges in India. One major concern is data privacy and security. AI systems require large amounts of data, making the protection of personal information essential.

Another challenge is the digital divide between urban and rural areas. Limited internet connectivity and technological infrastructure can hinder AI adoption. Ethical issues such as algorithmic bias, transparency, and accountability must also be addressed to ensure fair and responsible AI use.

There is also a need for strong regulatory frameworks to govern AI development and deployment while encouraging innovation. Collaboration among government, industry, academia, and society is essential for overcoming these challenges.

## Government Initiatives

The Government of India has recognized the importance of AI for national development. Various initiatives promote AI research, innovation, and adoption across sectors. Efforts are being made to develop AI talent, support startups, and encourage public-private partnerships.

Digital infrastructure improvements, startup ecosystems, and investments in research institutions are helping India build a strong AI ecosystem. The country's focus on digital transformation positions it well to become a global leader in AI technologies.

## Future of AI in India

The future of AI in India is highly promising. With a growing digital economy, increasing internet penetration, and a large pool of skilled professionals, India has the potential to become a global AI powerhouse. AI can help solve major challenges related to healthcare, agriculture, education, urbanization, and environmental sustainability.

Emerging technologies such as generative AI, robotics, autonomous systems, and intelligent automation will further accelerate innovation. Responsible AI development, ethical practices, and inclusive growth will be key to ensuring that the benefits of AI reach all sections of society.

## Conclusion

Artificial Intelligence is reshaping India's economy and society by driving innovation, improving efficiency, and enhancing the quality of life. Its applications in healthcare, agriculture, education, governance, finance, manufacturing, and transportation demonstrate its transformative potential. While challenges such as data privacy, ethical concerns, and workforce adaptation need careful attention, the opportunities presented by AI far outweigh the risks.

By investing in education, infrastructure, research, and responsible governance, India can harness the full potential of AI for sustainable and inclusive development. As the nation progresses towards becoming a digital economy, Artificial Intelligence will play a crucial role in building a smarter, more prosperous, and globally competitive India.
"""

# %%
essay2 = """# Role of AI in India

AI means Artifical Intelligence. AI is very populer in todays world. AI is a computer technolgy which can think and do works like humans. AI is growing very fast in India and many people are using AI for many purpose. AI is good for India because it help peoples and make life easy.

AI is used in many fields. In education students use AI for study and solving problems. Teachers also use AI for making notes and checking papers. Many students use ChatGPT and Gemini for homework and projects. It save lot of time and energy.

In hospital AI is also very important. Doctors can use AI to check disease and give treatment. AI machine can find many illness fastly. During corona also AI was helpful in many countries. In future AI will make hospitals better.

AI is helping farmers also. India is a agriculture country and many peoples are farmers. AI can tell about weather and crops. It can help farmers to know when to put water and fertilizers. This increase crop production and reduce loss.

In banks AI is used for online banking and security. Many banks use AI chatbots for customer support. AI can stop frauds and save money. UPI and online payments are becoming more safe because of AI technology.

Government is also using AI in India. AI can control traffic and help police. Smart cities are using AI for cameras and safety. Government can use AI for making good decisions for peoples.

AI also create jobs but some people think AI will take jobs. This is a problem because many workers can lose there jobs. But AI also create new jobs for computer engineers and software peoples. So people should learn AI for better future.

There are some disadvantages of AI. AI can make mistakes. Sometimes wrong information is given by AI. Many students become lazy because they copy answers from AI. AI also need internet and electricity. Some people misuse AI for bad things like fake videos and cheating.

India is developing country and AI can help India to become developed country. Many companies are investing in AI. Young generation is very interested in AI and new technology. India have many talented engineers who can make good AI systems.

In conclusion, AI is very useful for India. It is helping in education, farming, hospitals, banks and many other sectors. There are some bad points also but if AI is used properly then it will be good for everyone. AI is the future of India and every person should know about AI because it is becoming very important day by day. AI will make India strong and modern country.
"""

# %%
essay3 = """role of ai in india

Ai is india and india is ai because now ai coming every where and peoples are using from mobile and laptop and sometime machine also. AI full form artificial but not natural inteligent and this thing make work but also dont make work because depend on situation.

First ai is good. Student use ai for study and not study also. Homework become homework and project become project by ai. Teacher sometime know sometime dont know. If question is hard ai answer and if answer hard then question easy.

India have many peoples and ai also many peoples using. Farmer doing farming with ai and crop growing because weather and weather is climate and climate changing because technology. Cow also important in village and village use ai maybe in future for milk production and tractor.

Hospital doctor patient medicine injection all this ai helping. If person sick then ai can detect maybe. If not detect then doctor detect. AI save life but life is important so ai important.

Bank have money and money need security and ai give security by password otp and online. Scammer also use ai so ai stopping ai and ai making ai problem also. This is modern generation.

Government also doing ai. Camera on road catch people and challan come home. Smart city becoming smart because smart peoples and ai both smart. If city not smart then ai can make smart somehow.

There are many advantage and disadvantage and both are there. Job gone because ai but job come because ai also. Student lazy because ai but student topper because ai also. Good bad both side coin two side.

India is developing country and developed country and in future more developed by ai because youth of india is future of country and country future is youth. Startup company opening and closing and opening again with ai. Every company saying ai ai ai because market.

Nowadays chatgpt gemini robot machine internet coding engineer software data science everything connected. If person not know ai then future maybe difficult maybe not difficult depend on person and family background and network connection.

At last ai is role in india and india role in ai. We should use ai but dont misuse ai because misuse is not use. Human brain is brain and computer brain is computer. Both should work together for country development and digital india and technology growth and better tomorrow for everyone and all the peoples and nation and society and future generation because future is future. Thanking you.
"""

# %%
class essayState(TypedDict):
    
    essay:str
    language_feedback:str
    analysis_feedback:str
    clarity_feedback:str
    overall_feedback:str
    individual_scores: Annotated[list[int],operator.add]
    avg_score: float

# %%
def evaluate_language(state:essayState):

    prompt = f'Evaluate the language quality of the following essay and provide a feedback and assign a score out of 10 \n {state["essay"]}'

    output = structred_model.invoke(prompt)

    return {'language_feedback':output.feedback, 'individual_scores':[output.score]}

# %%
def evaluate_analysis(state : essayState):

    prompt = f'Evaluate the depth of analysis of the following essay and provide a feedback and assign a score out of 10 \n {state["essay"]}'

    output = structred_model.invoke(prompt)

    return {'analysis_feedback':output.feedback, 'individual_scores':[output.score]}

# %%
def evaluate_thought(state: essayState):

    prompt = f'Evaluate the clarity of thought of the following essay and provide a feedback and assign a score out of 10 \n {state["essay"]}'

    output = structred_model.invoke(prompt)

    return {'clarity_feedback':output.feedback, 'individual_scores':[output.score]}

# %%
def final_evaluation(state:essayState):

    # summary feedback
    prompt = f'Based on the following feedbacks create a summarized feedback \n language feedback - {state["language_feedback"]} \n depth of analysis feedback - {state["analysis_feedback"]} \n clarity of thought - {state["clarity_feedback"]}'
    overall_feedback = model.invoke(prompt).content

    # avg score
    avg_score = sum(state['individual_scores'])/len(state['individual_scores'])

    return {'overall_feedback':overall_feedback, 'avg_score':avg_score}

# %%
graph = StateGraph(essayState)

graph.add_node('evaluate_language',evaluate_language)
graph.add_node('evaluate_analysis',evaluate_analysis)
graph.add_node('evaluate_thought',evaluate_thought)
graph.add_node('final_evaluation',final_evaluation)


# Remove the parallel START edges and replace them with a sequence
graph.add_edge(START, 'evaluate_language')
graph.add_edge('evaluate_language', 'evaluate_analysis')
graph.add_edge('evaluate_analysis', 'evaluate_thought')
graph.add_edge('evaluate_thought', 'final_evaluation')
graph.add_edge('final_evaluation', END)

workflow = graph.compile()

# %%
initial_state = {
    'essay': essay3
}

try:
    result = workflow.invoke(initial_state)
    print(result)
except Exception as e:
    print("Workflow invocation failed:", e)
# Out:
# Workflow invocation failed: Error calling model 'gemini-2.5-flash' (RESOURCE_EXHAUSTED): 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash\nPlease retry in 8.532892603s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel-FreeT
# ...
